# %%
import pandas as pd
import numpy as np

# %%
weather_data = pd.read_csv('weather_data1.csv')

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data.shape
# Out:
# (6, 4)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
len(weather_data)
# Out:
# 6

# %%
weather_data[1:4]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
weather_data['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
weather_data[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
weather_data[weather_data['temperature']>30]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data[['day','temperature']] [weather_data['temperature']>30]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
np.std(weather_data['temperature'],ddof=1)
# Out:
# 3.8297084310253524

# %%
weather_data['temperature'].std()
# Out:
# 3.8297084310253524

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df = pd.read_csv('weather_datam.csv')

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35      -9999  Sunny
# 2  01-03-2017        -9999          2      0
# 3  01-04-2017           24          7   Snow
# 4  01-05-2017           32          4   Rain
# 5  01-06-2017        -9999          2  Sunny

# %%
df1 = df.replace(-9999,value=np.nan)

# %%
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        NaN  Sunny
# 2  01-03-2017          NaN        2.0      0
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain
# 5  01-06-2017          NaN        2.0  Sunny

# %%
df1 = df1.replace(0,df1['event'].mode())

# %%
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        NaN  Sunny
# 2  01-03-2017          NaN        2.0      0
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain
# 5  01-06-2017          NaN        2.0  Sunny

# %%
df1['event'].mode()
# Out:
# 0     Rain
# 1    Sunny
# Name: event, dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
plt.scatter(x=x,y=y) 

plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
plt.scatter(x,y)

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'r--')
plt.subplot(2,2,4)
plt.plot(x,y,'r--')

# %%
y = 3*x + 5

# %%
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,4*np.pi,0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
x = np.arange(1,4*np.pi,0.1)
y = np.cos(x)
plt.plot(x,y)

# %% [markdown]
# -------------------

# %%
df = pd.read_csv('tips.csv')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_4080\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.displot(df['tip'])

# %% [markdown]
# # Categorical Plots

# %%
sns.countplot(x='sex',data =df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='smoker',y='total_bill',data =df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data =df,palette='magma')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df,palette='ch:start=.2,rot=-.3')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### HW - Analyse the iris Dataset with different plots

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.pairplot(df,hue='Species',palette='magma')

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=df,palette='magma')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.heatmap(df.drop(columns = ['Species'],axis=1))
# Out:
# <Axes: >
